# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' ## TO DO set in docker

import gzip
import shutil
import requests

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from ctd import get_data
from ctd.utils import get_disease_hierarchy

from src.disease_classifier import DiseaseClassifier

# %%
input_df = get_data('ChemicalDiseaseInteractions')

# %% [markdown]
# ## No class weights or over sampling

# %%
no_treatment_kw = {
    'input_df': input_df,
    'parent_disease': 'MESH:D019636', # neurodegenerative diseases
    'gene_count': 100,
    'show_plots': True,
    'use_gene_inference_score': True,
    'use_class_weights': False,
    'oversample': False
}
no_treatment_dc = DiseaseClassifier(**no_treatment_kw)
no_treatment_dc_mm, _ = no_treatment_dc.main()
# Out:
# 374/374 [==============================] - 1s 2ms/step

# %% [markdown]
# ## Class Weights

# %%
class_weights_kw = {
    'input_df': input_df,
    'parent_disease': 'MESH:D019636', # neurodegenerative diseases
    'gene_count': 100,
    'show_plots': True,
    'use_gene_inference_score': True,
    'use_class_weights': True,
    'oversample': False
}
class_weights_dc = DiseaseClassifier(**class_weights_kw)
class_weights_dc_mm, _ = class_weights_dc.main()
# Out:
# 374/374 [==============================] - 1s 3ms/step

# %% [markdown]
# ## Oversampling

# %%
over_sampling_kw = {
    'input_df': input_df,
    'parent_disease': 'MESH:D019636', # neurodegenerative diseases
    'gene_count': 100,
    'show_plots': True,
    'use_gene_inference_score': True,
    'use_class_weights': False,
    'oversample': True
}
over_sampling_dc = DiseaseClassifier(**over_sampling_kw)
over_sampling_dc_mm, _ = over_sampling_dc.main()
# Out:
# 374/374 [==============================] - 1s 2ms/step

# %%
# analyze tradeoffs between the techniques, Recall + Precision + F1, what does that say about our approaches
df = pd.DataFrame.from_dict({
         'over_sampling': over_sampling_dc_mm,
         'class_weights': class_weights_dc_mm,
         'no_treatment': no_treatment_dc_mm}
, orient='columns')

df_selected = df.loc[['loss', 'accuracy', 'precision', 'recall', 'tp', 'fp', 'tn', 'fn']]
display(df_selected)
# Out:
#           over_sampling class_weights no_treatment
# loss           0.112404      0.175896     0.022575
# accuracy       0.955379      0.925324     0.995563
# precision       0.15192      0.102145     0.946429
# recall         0.784483      0.884956     0.514563
# tp                 91.0         100.0         53.0
# fp                508.0         879.0          3.0
# tn              11321.0       10953.0      11839.0
# fn                 25.0          13.0         50.0

# %% [markdown]
# ## Iterate over a number of different permutations

# %%
import time
import json
import datetime
from itertools import product

parent_disease = 'MESH:D019636'
permutations = []
for gene_count in range(25, 525, 25):
    permutations.append({'parent_disease': parent_disease, 'gene_count': gene_count, 'oversample':True, 'use_class_weights': False})
    permutations.append({'parent_disease': parent_disease, 'gene_count': gene_count, 'oversample':False, 'use_class_weights': True})
    permutations.append({'parent_disease': parent_disease, 'gene_count': gene_count, 'oversample':False, 'use_class_weights': False})

results = []
for i, (p) in enumerate(permutations):
    p['input_df'] = input_df
    p['show_plots'] = False
    _m = DiseaseClassifier(**p)
    
    model_results, _ = _m.main()
    with open('out_stream.txt', 'a') as f:
        f.write(json.dumps(model_results) + '\n')
    results.append(model_results)

df = pd.DataFrame(results)

now = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
df.to_csv('final-output/{ts}.csv'.format(ts=now))
# Out:
# 293/293 [==============================] - 1s 2ms/step
# 293/293 [==============================] - 1s 2ms/step
# 293/293 [==============================] - 1s 2ms/step
# 339/339 [==============================] - 1s 2ms/step
# 339/339 [==============================] - 1s 2ms/step
# 339/339 [==============================] - 1s 2ms/step
# 357/357 [==============================] - 1s 2ms/step
# 357/357 [==============================] - 1s 2ms/step
# 357/357 [==============================] - 1s 2ms/step
# 374/374 [==============================] - 1s 3ms/step
# 374/374 [==============================] - 1s 2ms/step
# 374/374 [==============================] - 1s 2ms/step
# 384/384 [==============================] - 1s 2ms/step
# 384/384 [==============================] - 1s 2ms/step
# 384/384 [==============================] - 1s 2ms/step
# 395/395 [==============================] - 1s 2ms/step
# 395/395 [==============================] - 1s 1ms/step
# 395/395 [==============================] - 1s 2ms/step
# 399/399 [==============================] - 1s 2ms/step
# 399/399 [==============================] - 1s 1ms/step
# 399/399 [==============================] - 1s 2ms/step
# 404/404 [==============================] - 1s 3ms/step
# 404/404 [==============================] - 1s 2ms/step
# 404/404 [==============================] - 1s 2ms/step
# 409/409 [==============================] - 1s 2ms/step
# 409/409 [==============================] - 1s 2ms/step
# 409/409 [==============================] - 1s 2ms/step
# 411/411 [==============================] - 1s 2ms/step
# 411/411 [==============================] - 1s 2ms/step
# 411/411 [==============================] - 1s 2ms/step
# 416/416 [==============================] - 1s 2ms/step
# 416/416 [==============================] - 1s 2ms/step
# 416/416 [==============================] - 1s 2ms/step
# 418/418 [==============================] - 1s 2ms/step
# 418/418 [==============================] - 1s 2ms/step
# 418/418 [==============================] - 1s 1ms/step
# 420/420 [==============================] - 1s 2ms/step
# 420/420 [==============================] - 1s 2ms/step
# 420/420 [==============================] - 1s 2ms/step
# 422/422 [==============================] - 1s 2ms/step
# 422/422 [==============================] - 2s 2ms/step
# 422/422 [==============================] - 1s 2ms/step
# 423/423 [==============================] - 1s 1ms/step
# 423/423 [==============================] - 1s 2ms/step
# 423/423 [==============================] - 1s 1ms/step
# 424/424 [==============================] - 1s 2ms/step
# 424/424 [==============================] - 2s 4ms/step
# 424/424 [==============================] - 1s 2ms/step
# 425/425 [==============================] - 1s 3ms/step
# 425/425 [==============================] - 1s 3ms/step
# 425/425 [==============================] - 1s 2ms/step
# 427/427 [==============================] - 1s 3ms/step
# 427/427 [==============================] - 2s 4ms/step
# 427/427 [==============================] - 1s 2ms/step
# 428/428 [==============================] - 1s 3ms/step
# 428/428 [==============================] - 2s 4ms/step
# 428/428 [==============================] - 2s 4ms/step
# 429/429 [==============================] - 2s 4ms/step
# 429/429 [==============================] - 2s 4ms/step
# 429/429 [==============================] - 1s 3ms/step

# %% [markdown]
# ## what are the best params to use?

# %%
import pandas as pd
import glob

from scipy.interpolate import make_interp_spline, BSpline

csv_files = glob.glob('final-output/*.csv')
csv_files.sort(key=os.path.getmtime, reverse=True)
most_recent_file = csv_files[0]
results_df = pd.read_csv(most_recent_file)

def get_plot(df, metric):
    x_axis = df['gene_count']
    xnew = np.linspace(0, max(x_axis), 300) 
    spl = make_interp_spline(df['gene_count'], df[metric], k=3)
    power_smooth = spl(xnew)
    return x_axis, df[metric]
    # return xnew, power_smooth

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 9))
dnn_df = results_df[(results_df['model_type'] == 'DNN')]

oversample_df = dnn_df[dnn_df['oversample']]
class_weight_df = dnn_df[dnn_df['use_class_weights']]
no_treatment_df = dnn_df[(dnn_df['oversample'] == False) & (dnn_df['use_class_weights'] == False)]

axes[0].plot(*get_plot(oversample_df, 'auc'), label='Over Sampling - Recall')
axes[0].plot(*get_plot(class_weight_df, 'auc'), label='Class Weight - Recall')
axes[0].plot(*get_plot(no_treatment_df, 'auc'), label='No Treatment - Recall')
axes[0].legend()

axes[1].plot(*get_plot(oversample_df, 'precision'), label='Over Sampling - Precision')
axes[1].plot(*get_plot(class_weight_df, 'precision'), label='Class Weight - Precision')
axes[1].plot(*get_plot(no_treatment_df, 'precision'), label='No Treatment - Precision')
axes[1].legend()


fig.tight_layout()

# %% [markdown]
# ## Multi Class with Neuodegenerative Diseases

# %%
kw = {
    'input_df': input_df,
    'parent_disease': 'MESH:D002318', # neurodegenerative diseases
    'gene_count': 100,
    'show_plots': True,
    'use_class_weights': True,
    'oversample': False,
    'classification': 'categorical'
}
cat = DiseaseClassifier(**kw)
mm, _ = cat.main()
# Out:
# 374/374 [==============================] - 1s 2ms/step

# %%
# instatiate the model to get the relevant genes that we need to process.. dont need to fit the model yet
kw = {
    'input_df': input_df,
    'parent_disease': 'MESH:D002318', # neurodegenerative diseases
    'gene_count': 100,
    'show_plots': False,
    'oversample': False,
    'use_class_weights': True,
    'classification': 'categorical'
}
dc = DiseaseClassifier(**kw)
chem_cl_metrics, chem_cl_model = dc.main()

inp_df = get_data('ChemicalGeneInteractions')
inp_df = inp_df[inp_df['GeneSymbol'].isin(dc.top_n_genes)]

## process the chemical -> dataset ( without disease ) in the same way we do our input data
gb_df = inp_df.groupby(['ChemicalName', 'GeneSymbol']).size().reset_index()
gb_df.columns = ['ChemicalName','GeneSymbol', 'InteractionCount']
dummy_df = pd.get_dummies(gb_df, prefix='', prefix_sep='',columns=['GeneSymbol'])

chem_df = dummy_df.groupby(['ChemicalName']).agg({np.max}).reset_index()
chem_df.columns = chem_df.columns.droplevel(1)

predicted_values = chem_cl_model.predict(chem_df[dc.top_n_genes])

predicted_value_df = pd.DataFrame(predicted_values, columns=['Ther', 'Not Relevant', 'Marker'])

final = chem_df.merge(predicted_value_df, left_index=True, right_index=True)
final = final[['ChemicalName', 'Ther', 'Not Relevant', 'Marker']]

print('--- THER ---')
display(final.nlargest(5, 'Ther'))

print('--- MARKER ---')
display(final.nlargest(5, 'Marker'))
# Out:
# 374/374 [==============================] - 1s 3ms/step
# 310/310 [==============================] - 1s 3ms/step
# --- THER ---
#                                          ChemicalName  Ther  Not Relevant  \
# 4                                    (+)-JQ1 compound   1.0  1.812097e-33
# 6   (1,2-bis(1,2-benzisoselenazolone-3(2H)-ketone)...   1.0  1.199213e-08
# 25  (3R)-((2,3-dihydro-5-methyl-3-((4-morpholinyl)...   1.0  4.133111e-20
# 63                              1',2'-dihydrorotenone   1.0  1.907271e-08
# 66                         1'-acetoxychavicol acetate   1.0  7.203452e-10
#
#           Marker
# 4   1.557691e-34
# 6   2.270026e-09
# 25  3.873881e-20
# 63  7.088216e-07
# 66  2.804950e-11
# --- MARKER ---
#            ChemicalName      Ther  Not Relevant    Marker
# 3754            LGM2605  0.025371      0.332234  0.749699
# 2319  Bandrowski's base  0.007401      0.591266  0.723376
# 2456            CC-8490  0.049947      0.308687  0.660406
# 6131       atractylodin  0.046568      0.497819  0.656925
# 7601     ginsenoside F1  0.046568      0.497819  0.656925

# %%
## ctd says (+)-JQ1 compound is associated with the reduction of inflamation
## pub chem says trimethyllead is acutely toxic - https://pubchem.ncbi.nlm.nih.gov/compound/Trimethyllead-acetate is ""

# %% [markdown]
# ## Understanding feature importance -- what genes are coorelated with Parkinsons / Neurodegenerative diseass ( Using a Linear Model )

# %%
kw = {
    'input_df': input_df,
    'parent_disease': 'MESH:D019636', # neurodegenerative diseases
    'gene_count': 100,
    'show_plots': True,
    'use_class_weights': True,
    'oversample': False,
    'model_type': 'LINEAR',
    'show_feature_importance': True
}
dc = DiseaseClassifier(**kw)
dc_mm, model = dc.main()

feature_importance = pd.DataFrame(dc_mm.get('feature_importance'))

# %%
melted_df = feature_importance.melt(var_name='Feature', value_name='Importance').sort_values('Importance', ascending=False)[:10]

ax = melted_df.plot(kind='bar', legend=True, x='Feature', y='Importance', figsize=(7, 4))
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
